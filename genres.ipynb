# %%
# Setup
import pandas as pd
import time
anime = pd.read_csv('data/anime_cleaned.csv')

# %%
# treat null values
anime['genre'].fillna('NA', inplace = True)

# separate all genres into one list, considering comma + space as separators
genre = anime['genre'].str.split(', ').tolist()

# flatten the list
flat_genre = [item for sublist in genre for item in sublist]

# convert to a set to make unique
set_genre = set(flat_genre)

# back to list
unique_genre = list(set_genre)

# remove NA
unique_genre.remove('NA')

# create columns by each unique genre
anime = anime.reindex(anime.columns.tolist() + unique_genre, axis=1, fill_value=0)

start = time.time()
# for each value inside column, update the dummy
for index, row in anime.iterrows():
    for val in row.genre.split(', '):
        if val != 'NA':
            anime.loc[index, val] = 1

end = time.time()
print(end - start)
# Out:
# 8.596707105636597

# %%
anime[['genre','Slice of Life', 'Supernatural','Romance', 'Shounen', 'Comedy', 'Thriller', 'Hentai', 'Shoujo']].head(20)
# Out:
#                                                 genre  Slice of Life  \
# 0              Comedy, Supernatural, Romance, Shounen              0
# 1            Comedy, Parody, Romance, School, Shounen              0
# 2                       Comedy, Magic, School, Shoujo              0
# 3              Comedy, Drama, Magic, Romance, Fantasy              0
# 4                     Comedy, Drama, Romance, Shounen              0
# 5                                Kids, School, Shoujo              0
# 6              Magic, Comedy, Romance, School, Shoujo              0
# 7   Action, Drama, Fantasy, Romance, School, Super...              0
# 8        Music, Slice of Life, Comedy, Romance, Josei              1
# 9              Comedy, Harem, Romance, School, Shoujo              0
# 10                 Comedy, Drama, Romance, Shounen Ai              0
# 11                    Comedy, Romance, School, Shoujo              0
# 12                 Comedy, Drama, Romance, Shounen Ai              0
# ...

# %%
anime.head()
# Out:
#    anime_id                title              title_english title_japanese  \
# 0     11013        Inu x Boku SS  Inu X Boku Secret Service         妖狐×僕SS
# 1      2104     Seto no Hanayome      My Bride is a Mermaid          瀬戸の花嫁
# 2      5262   Shugo Chara!! Doki         Shugo Chara!! Doki    しゅごキャラ！！どきっ
# 3       721        Princess Tutu              Princess Tutu      プリンセスチュチュ
# 4     12365  Bakuman. 3rd Season                   Bakuman.          バクマン。
#
#                                   title_synonyms  \
# 0                                Youko x Boku SS
# 1                           The Inland Sea Bride
# 2  Shugo Chara Ninenme, Shugo Chara! Second Year
# 3                                            NaN
# 4                               Bakuman Season 3
#
#                                            image_url type    source  episodes  \
# 0  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga        12
# ...

# %%
anime.to_csv('anime_with_genre_separated.csv')
